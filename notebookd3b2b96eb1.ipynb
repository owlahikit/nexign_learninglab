# %%
# установка библиотеки
# !pip install ultralytics

# %%
# !pip install tensorboard

# %%
# импорт библиотеки ultralytics
from ultralytics import YOLO

# сборка модели
model = YOLO('yolov8m-seg.yaml')  # сборка модели из официального YAML-файла
model = YOLO('yolov8m-seg.pt')  # загрузка предобученной модели (рекомендовано)
model = YOLO('yolov8m-seg.yaml').load('yolov8m-seg.pt')  # создает экземпляр модели YOLO с заданной конфигурацией

# обучение модели на пользовательских данных (не забудьте прописать пути в data.yaml)
results = model.train(data='/kaggle/input/123456/data.yaml', epochs=30,device='cuda', imgsz=900)
# Out:
# Transferred 537/537 items from pretrained weights
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
# импорт библиотеки os
import os

# обращение к весам модели
model = YOLO('yolov8n-seg.pt')  # предобученные веса
model = YOLO('/kaggle/working/runs/segment/train/weights/best.pt')  # кастомные веса после дообучения YOLO

# получение результатов изображения (в скобках указываем путь к изображению, объекты на котором нужно детектировать)

# %%
results = model('/kaggle/input/photo-yolo/11385.jpg')
print(type(results))
# сохранение изображения
if results:
    # если объекты найдены, то изображение сохраняется с именем result_№.jpg
    for i, result in enumerate(results):
        save_path = os.path.join('/kaggle/working/', f'result_{i}.jpg')
        result.save(save_path)
else:
    # если объекты не детектировались, то выводится сообщение
    print("No objects detected.")
# Out:
# image 1/1 /kaggle/input/photo-yolo/11385.jpg: 800x608 1 Другая реклама, 1 Реклама Megafon, 1 Реклама Yota, 8.4ms
# Speed: 3.5ms preprocess, 8.4ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 608)

# %%
from PIL import Image
# загрузка изображения
img = Image.open(f'/kaggle/working/result_0.jpg')
# вывод изображения
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1440>

# %%
# загрузка изображения
img = Image.open('/content/runs/detect/train/results.png')
# вывод изображения
display(img)

# %%
# скачивание размеченного датасета с roboflow
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="IV0Lx75EGDX8Bz32ji5a")
project = rf.workspace("project-j7kze").project("cv_lecture_segmentation")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# установка библиотеки
# !pip install ultralytics

# %%
# импорт библиотеки ultralytics
from ultralytics import YOLO

# сборка модели
model = YOLO('yolov8n-seg.yaml')  # сборка модели из официального YAML-файла
model = YOLO('yolov8n-seg.pt')  # загрузка предобученной модели (рекомендовано)
model = YOLO('yolov8n-seg.yaml').load('yolov8n.pt')  # создает экземпляр модели YOLO с заданной конфигурацией

# обучение модели на пользовательских данных
results = model.train(data='/content/cv_lecture_segmentation-1/data.yaml', epochs=15, imgsz=640)
